# %% [markdown]
# # Module 1.09: Diagnostics — The Big Picture (v2)
#
# > **Goal:** Compute time series diagnostics and understand what patterns exist in our portfolio.
#
# **5Q Lens:** Q4 (Data & Drivers) — Measure structure & chaos across portfolio

# %% [markdown]
# ---
#
# ## 1. Setup

# %%
import warnings
import numpy as np
import pandas as pd
from tsfeatures import tsfeatures
import forecast_foundations as ff
from tsforge.eda.ts_features_extension import ADI
import tsforge as tsf

# NEW: Import from unified plots API
from tsforge.plots import (
    plot_portfolio_metrics,  # Convenience wrapper for portfolio metrics
    plot_bar,plot_distribution)

# Settings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---
# ## 2. Load Data

# %%
# Load the forecast-ready dataset from Module 1.08
weekly_df = pd.read_parquet('./data/1.08_data_preparation_output.parquet')

# %%
# Quick sanity check
weekly_df.head(3)
# Out:
#           unique_id         ds    y  is_gap      item_id store_id  dept_id  \
# 0  FOODS_1_001_CA_1 2011-01-23  3.0       0  FOODS_1_001     CA_1  FOODS_1
# 1  FOODS_1_001_CA_1 2011-01-30  9.0       0  FOODS_1_001     CA_1  FOODS_1
# 2  FOODS_1_001_CA_1 2011-02-06  7.0       0  FOODS_1_001     CA_1  FOODS_1
#
#   cat_id state_id  wm_yr_wk  ...  year  snap_CA  snap_TX  snap_WI  \
# 0  FOODS       CA     11101  ...  2011        0        0        0
# 1  FOODS       CA     11101  ...  2011        1        1        1
# 2  FOODS       CA     11102  ...  2011        1        1        1
#
#    event_name_1 event_name_2 event_name_3 event_type_1 event_type_2  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2     SuperBowl          NaN          NaN     Sporting          NaN
#
#   event_type_3
# 0          NaN
# 1          NaN
# 2          NaN
#
# [3 rows x 21 columns]

# %% [markdown]
# ---
#
# <div style="text-align: center;">
#
# ## 3. Compute Diagnostics
#
# <div style="background: linear-gradient(135deg, #2E86AB 0%, #1a5276 100%); color: white; padding: 12px 20px; border-radius: 8px; margin: 10px auto; max-width: 600px;">
# <strong>What patterns exist in the data?</strong><br>
# <em>50+ metrics from  tsfeatures + tsforge that describe trend, seasonality, noise, intermittency, and more.</em>
# </div>
#
# </div>

# %% [markdown]
# ### 3.1 Calculate diagnostics from `tsfeatures`
#
# `tsfeatures` extracts dozens of time series characteristics automatically — this is our first systematic look at the portfolio.

# %%
diagnostics = tsfeatures(weekly_df, freq=52, threads=8)  # All defaults
adi_df = (weekly_df.groupby('unique_id')['y'].apply(lambda y: ADI(y.values, freq=52)["adi"]).reset_index(name='adi'))
diagnostics = diagnostics.merge(adi_df, on='unique_id')
# Out:
# ✓ Loaded 'diagnostics'
#    Module: 1_09 | Shape: 30,490 × 43

# %% [markdown]
# ### 3.3 Merge Hierarchy Metadata
#
# Attach business dimensions so we can slice diagnostics by department, category, store.

# %%
# Get hierarchy from original data
hierarchy = (
    weekly_df[['unique_id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']]
    .drop_duplicates(subset=['unique_id'])
)

# Merge
diagnostics = diagnostics.merge(hierarchy, on='unique_id', how='left')

# %% [markdown]
# ### 3.4 Preview Key Metrics

# %%
KEY_METRICS = ['trend', 'seasonal_strength', 'entropy', 'adi']

diagnostics[['unique_id', 'cat_id', 'dept_id'] + KEY_METRICS].head(10)
# Out:
#           unique_id cat_id  dept_id     trend  seasonal_strength   entropy  \
# 0  FOODS_1_001_CA_1  FOODS  FOODS_1  0.204450           0.376623  0.850729
# 1  FOODS_1_001_CA_2  FOODS  FOODS_1  0.223280           0.439298  0.843529
# 2  FOODS_1_001_CA_3  FOODS  FOODS_1  0.162804           0.384099  0.895521
# 3  FOODS_1_001_CA_4  FOODS  FOODS_1  0.110839           0.479389  0.873170
# 4  FOODS_1_001_TX_1  FOODS  FOODS_1  0.260977           0.376637  0.866836
# 5  FOODS_1_001_TX_2  FOODS  FOODS_1  0.212788           0.397528  0.855971
# 6  FOODS_1_001_TX_3  FOODS  FOODS_1  0.048173           0.417552  0.886295
# 7  FOODS_1_001_WI_1  FOODS  FOODS_1  0.287522           0.423122  0.837675
# 8  FOODS_1_001_WI_2  FOODS  FOODS_1  0.392052           0.434856  0.828196
# 9  FOODS_1_001_WI_3  FOODS  FOODS_1  0.466792           0.466487  0.828913
#
#         adi
# 0  1.105469
# 1  1.105469
# 2  1.118577
# 3  1.276018
# 4  1.200855
# 5  1.156379
# 6  1.181435
# 7  1.119522
# 8  1.288991
# 9  1.524324

# %% [markdown]
# ---
#
# <div style="text-align: center;">
#
# ## 4. Structure & Chaos Overview
#
# <div style="background: linear-gradient(135deg, #4A90A4 0%, #2d5a6b 100%); color: white; padding: 12px 20px; border-radius: 8px; margin: 10px auto; max-width: 600px;">
# <strong>One view of all key metrics</strong><br>
# <em>Structure (trend, seasonality) vs Chaos (entropy, intermittency, variability)</em>
# </div>
#
# </div>

# %%
# Single call to visualize all key metrics
# Includes: histogram + KDE, median line, threshold with percentage

plot_distribution(
    diagnostics,
    columns=['trend', 'seasonal_strength', 'entropy', 'adi'],
    mode='facet',
    wrap=2,
    use_metric_defaults=True,  # Auto: thresholds, colors, clipping
    show_kde=True,
    show_median=True,
    show_threshold_pct=True,
)

# %% [markdown]
# ---
#
# <div style="text-align: center;">
#
# ## 5. Deep Dive: Individual Metrics
#
# </div>

# %% [markdown]
# ### 5.1 Structure Metrics (Learnable Patterns)

# %%
# Focus on structure metrics only (blue coloring)
plot_portfolio_metrics(
    diagnostics,
    metrics=['trend', 'seasonal_strength'],
    bins=40,
    wrap=2,
    show_kde=True,
    show_median=True,
    show_threshold=True,
    style={"title": "Structure Metrics: Trend & Seasonality"},
)

# %% [markdown]
# ### 5.2 Chaos Metrics (Unpredictability)

# %%
# Focus on chaos metrics (orange coloring, auto-clipped for outliers)
plot_portfolio_metrics(
    diagnostics,
    metrics=['entropy', 'adi', 'cv2', 'lumpiness'],
    bins=40,
    wrap=2,
    show_kde=True,
    show_median=True,
    show_threshold=True,
    style={"title": "Chaos Metrics: Entropy, Intermittency, Variability"},
)

# %% [markdown]
# ---
# <div style="text-align: center;">
#
# ## 6. Portfolio Summary by Segment
#
# </div>

# %% [markdown]
# ### 6.1 By Category

# %%
from tsforge.display import style_heatmap_table

display(style_heatmap_table(
    diagnostics, 'cat_id', KEY_METRICS,
    'Mean Diagnostics by Category'
))
# Out:
# <style type="text/css">
# #T_e80f8 caption {
#   font-size: 14px;
#   font-weight: bold;
#   padding: 10px;
# }
# #T_e80f8_row0_col0, #T_e80f8_row0_col1, #T_e80f8_row2_col2, #T_e80f8_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e80f8_row0_col2, #T_e80f8_row0_col3, #T_e80f8_row2_col0, #T_e80f8_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_e80f8_row1_col0 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_e80f8_row1_col1 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_e80f8_row1_col2 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_e80f8_row1_col3 {
#   background-color: #fece7c;
#   color: #000000;
# }
# </style>
# <table id="T_e80f8" class="dataframe tsforge-heatmap">
#   <caption>Mean Diagnostics by Category</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e80f8_level0_col0" class="col_heading level0 col0" >trend</th>
#       <th id="T_e80f8_level0_col1" class="col_heading level0 col1" >seasonal_strength</th>
#       <th id="T_e80f8_level0_col2" class="col_heading level0 col2" >entropy</th>
#       <th id="T_e80f8_level0_col3" class="col_heading level0 col3" >adi</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cat_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e80f8_level0_row0" class="row_heading level0 row0" >HOBBIES</th>
#       <td id="T_e80f8_row0_col0" class="data row0 col0" >0.332</td>
#       <td id="T_e80f8_row0_col1" class="data row0 col1" >0.559</td>
#       <td id="T_e80f8_row0_col2" class="data row0 col2" >0.838</td>
#       <td id="T_e80f8_row0_col3" class="data row0 col3" >1.625</td>
#     </tr>
#     <tr>
#       <th id="T_e80f8_level0_row1" class="row_heading level0 row1" >HOUSEHOLD</th>
#       <td id="T_e80f8_row1_col0" class="data row1 col0" >0.357</td>
#       <td id="T_e80f8_row1_col1" class="data row1 col1" >0.572</td>
#       <td id="T_e80f8_row1_col2" class="data row1 col2" >0.820</td>
#       <td id="T_e80f8_row1_col3" class="data row1 col3" >1.520</td>
#     </tr>
#     <tr>
#       <th id="T_e80f8_level0_row2" class="row_heading level0 row2" >FOODS</th>
#       <td id="T_e80f8_row2_col0" class="data row2 col0" >0.445</td>
#       <td id="T_e80f8_row2_col1" class="data row2 col1" >0.598</td>
#       <td id="T_e80f8_row2_col2" class="data row2 col2" >0.776</td>
#       <td id="T_e80f8_row2_col3" class="data row2 col3" >1.339</td>
#     </tr>
#   </tbody>
# </table>

# %%
# NEW: Visualize category comparison with bar chart
cat_summary = diagnostics.groupby('cat_id')[KEY_METRICS].mean().reset_index()

# Show trend by category
plot_bar(
    cat_summary,
    x='cat_id',
    y='trend',
    orientation='h',
    sort_by='trend',
    sort_ascending=False,
    show_values=True,
    value_format='.3f',
    thresholds=[0.5],
    threshold_labels=['Strong Trend'],
    style={"title": "Mean Trend Strength by Category"},
)

# %% [markdown]
# ### 6.2 By Department

# %%
display(style_heatmap_table(
    diagnostics, 'dept_id', KEY_METRICS,
    'Mean Diagnostics by Department'
))
# Out:
# <style type="text/css">
# #T_6f6e4 caption {
#   font-size: 14px;
#   font-weight: bold;
#   padding: 10px;
# }
# #T_6f6e4_row0_col0 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_6f6e4_row0_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_6f6e4_row0_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_6f6e4_row0_col3 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_6f6e4_row1_col0 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_6f6e4_row1_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_6f6e4_row1_col2, #T_6f6e4_row1_col3, #T_6f6e4_row5_col0, #T_6f6e4_row5_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_6f6e4_row2_col0 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_6f6e4_row2_col1 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_6f6e4_row2_col2 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_6f6e4_row2_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_6f6e4_row3_col0, #T_6f6e4_row4_col1, #T_6f6e4_row6_col2, #T_6f6e4_row6_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6f6e4_row3_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_6f6e4_row3_col2 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_6f6e4_row3_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_6f6e4_row4_col0 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_6f6e4_row4_col2 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_6f6e4_row4_col3 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_6f6e4_row5_col2 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_6f6e4_row5_col3 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_6f6e4_row6_col0 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_6f6e4_row6_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# </style>
# <table id="T_6f6e4" class="dataframe tsforge-heatmap">
#   <caption>Mean Diagnostics by Department</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f6e4_level0_col0" class="col_heading level0 col0" >trend</th>
#       <th id="T_6f6e4_level0_col1" class="col_heading level0 col1" >seasonal_strength</th>
#       <th id="T_6f6e4_level0_col2" class="col_heading level0 col2" >entropy</th>
#       <th id="T_6f6e4_level0_col3" class="col_heading level0 col3" >adi</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dept_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f6e4_level0_row0" class="row_heading level0 row0" >HOBBIES_1</th>
#       <td id="T_6f6e4_row0_col0" class="data row0 col0" >0.345</td>
#       <td id="T_6f6e4_row0_col1" class="data row0 col1" >0.542</td>
#       <td id="T_6f6e4_row0_col2" class="data row0 col2" >0.826</td>
#       <td id="T_6f6e4_row0_col3" class="data row0 col3" >1.484</td>
#     </tr>
#     <tr>
#       <th id="T_6f6e4_level0_row1" class="row_heading level0 row1" >HOBBIES_2</th>
#       <td id="T_6f6e4_row1_col0" class="data row1 col0" >0.297</td>
#       <td id="T_6f6e4_row1_col1" class="data row1 col1" >0.607</td>
#       <td id="T_6f6e4_row1_col2" class="data row1 col2" >0.871</td>
#       <td id="T_6f6e4_row1_col3" class="data row1 col3" >2.017</td>
#     </tr>
#     <tr>
#       <th id="T_6f6e4_level0_row2" class="row_heading level0 row2" >HOUSEHOLD_1</th>
#       <td id="T_6f6e4_row2_col0" class="data row2 col0" >0.430</td>
#       <td id="T_6f6e4_row2_col1" class="data row2 col1" >0.596</td>
#       <td id="T_6f6e4_row2_col2" class="data row2 col2" >0.792</td>
#       <td id="T_6f6e4_row2_col3" class="data row2 col3" >1.304</td>
#     </tr>
#     <tr>
#       <th id="T_6f6e4_level0_row3" class="row_heading level0 row3" >HOUSEHOLD_2</th>
#       <td id="T_6f6e4_row3_col0" class="data row3 col0" >0.283</td>
#       <td id="T_6f6e4_row3_col1" class="data row3 col1" >0.547</td>
#       <td id="T_6f6e4_row3_col2" class="data row3 col2" >0.849</td>
#       <td id="T_6f6e4_row3_col3" class="data row3 col3" >1.743</td>
#     </tr>
#     <tr>
#       <th id="T_6f6e4_level0_row4" class="row_heading level0 row4" >FOODS_1</th>
#       <td id="T_6f6e4_row4_col0" class="data row4 col0" >0.358</td>
#       <td id="T_6f6e4_row4_col1" class="data row4 col1" >0.539</td>
#       <td id="T_6f6e4_row4_col2" class="data row4 col2" >0.803</td>
#       <td id="T_6f6e4_row4_col3" class="data row4 col3" >1.372</td>
#     </tr>
#     <tr>
#       <th id="T_6f6e4_level0_row5" class="row_heading level0 row5" >FOODS_2</th>
#       <td id="T_6f6e4_row5_col0" class="data row5 col0" >0.475</td>
#       <td id="T_6f6e4_row5_col1" class="data row5 col1" >0.641</td>
#       <td id="T_6f6e4_row5_col2" class="data row5 col2" >0.777</td>
#       <td id="T_6f6e4_row5_col3" class="data row5 col3" >1.408</td>
#     </tr>
#     <tr>
#       <th id="T_6f6e4_level0_row6" class="row_heading level0 row6" >FOODS_3</th>
#       <td id="T_6f6e4_row6_col0" class="data row6 col0" >0.454</td>
#       <td id="T_6f6e4_row6_col1" class="data row6 col1" >0.592</td>
#       <td id="T_6f6e4_row6_col2" class="data row6 col2" >0.768</td>
#       <td id="T_6f6e4_row6_col3" class="data row6 col3" >1.297</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Department comparison: ADI (intermittency)
dept_summary = diagnostics.groupby('dept_id')[KEY_METRICS].mean().reset_index()

plot_bar(
    dept_summary,
    x='dept_id',
    y='adi',
    orientation='h',
    sort_by='adi',
    sort_ascending=False,
    show_values=True,
    value_format='.2f',
    thresholds=[1.32],
    threshold_labels=['Intermittent'],
    style={"title": "Mean ADI (Intermittency) by Department"},
)

# %% [markdown]
# ---
#
# ## 7. Save Output

# %%
# Save diagnostics for downstream modules
diagnostics.to_parquet('./1.09_diagnostics.parquet', index=False)
